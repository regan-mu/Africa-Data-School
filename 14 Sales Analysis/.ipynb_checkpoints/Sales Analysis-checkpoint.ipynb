# %% [markdown]
# ## Sales Analysis

# %% [markdown]
# - In this section we are going to to analyze and answer business questions about 12 months worth of sales data.
# - The data contains hundreds of thousands of electronics store purchase records broken down by month, product type, cost, purchase address, etc.

# %% [markdown]
#  In this section we explore 5 high level business questions related to our data:
#
# * What was the best month for sales? How much was earned that month?
# * What city sold the most product?
# * What time should we display advertisements to maximize the likelihood of customer’s buying product?
# * What products are most often sold together?
# * What product sold the most? Why do you think it sold the most?

# %%
import pandas as pd
import os

# %% [markdown]
# ### Merge 12 month of sales data
# - Since data is organized in months, we need to merge all the months to one dataframe.

# %%
#Start with an empty dataframe that will contain 12 month data.
all_months_data = pd.DataFrame()
files =[file for file in os.listdir('./Sales_Data')]
for file in files:
    df = pd.read_csv('./Sales_Data/' + file)
    all_months_data = pd.concat([all_months_data, df])

# %%
df.head()
# Out:
#   Order ID                Product Quantity Ordered Price Each      Order Date  \
# 0   248151  AA Batteries (4-pack)                4       3.84  09/17/19 14:44
# 1   248152   USB-C Charging Cable                2      11.95  09/29/19 10:19
# 2   248153   USB-C Charging Cable                1      11.95  09/16/19 17:48
# 3   248154       27in FHD Monitor                1     149.99  09/27/19 07:52
# 4   248155   USB-C Charging Cable                1      11.95  09/01/19 19:03
#
#                         Purchase Address
# 0    380 North St, Los Angeles, CA 90001
# 1           511 8th St, Austin, TX 73301
# 2  151 Johnson St, Los Angeles, CA 90001
# 3      355 Hickory St, Seattle, WA 98101
# 4          125 5th St, Atlanta, GA 30301

# %% [markdown]
# ### Save the dataframe to CSV file.

# %%
all_months_data.to_csv('all_data.csv', index=False)

# %% [markdown]
# ### Read the new csv containing all data

# %%
data = pd.read_csv('all_data.csv')

# %%
data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %% [markdown]
# ### Clean up the data
#
# - You need to figure out what we need to clean.
# - You find things you need to clean as you perform operations and get errors.
# - Based on the error, you decide how you should go about cleaning the data.

# %% [markdown]
# ###### Find missing values

# %%
nan_df = data[data.isna().any(axis=1)]
nan_df.head()
# Out:
#      Order ID Product Quantity Ordered Price Each Order Date Purchase Address
# 1         NaN     NaN              NaN        NaN        NaN              NaN
# 356       NaN     NaN              NaN        NaN        NaN              NaN
# 735       NaN     NaN              NaN        NaN        NaN              NaN
# 1433      NaN     NaN              NaN        NaN        NaN              NaN
# 1553      NaN     NaN              NaN        NaN        NaN              NaN

# %%
data.isna().any(axis=1)
# Out:
# 0         False
# 1          True
# 2         False
# 3         False
# 4         False
#           ...
# 186845    False
# 186846    False
# 186847    False
# 186848    False
# 186849    False
# Length: 186850, dtype: bool

# %% [markdown]
# ###### Dropping rows with missing values

# %%
all_data = data.dropna(how='all').reset_index(drop=True)
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
# 2   176560                Google Phone                1        600
# 3   176560            Wired Headphones                1      11.99
# 4   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %%
all_data.isna().any(axis=1)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 186300    False
# 186301    False
# 186302    False
# 186303    False
# 186304    False
# Length: 186305, dtype: bool

# %% [markdown]
# ###  Checking for duplicates
# - Often we see duplicated rows of data in a DataFrame.
# - This could happen due to erros in data collection or in saving and loading data.
# - We can check for duplicates using pandas .duplicated() method.

# %%
all_data.duplicated().value_counts()
# Out:
# False    185687
# True        618
# dtype: int64

# %%
all_data.shape
# Out:
# (186305, 6)

# %% [markdown]
# ### Dropping Duplicates
# - Duplicates always don't add any value to the dataset and can cause bias in Ml Models.
# - Its good to drop the duplicate values.
# - We use .drop_duplicates method.

# %%
all_data.drop_duplicates(inplace=True)

# %%
all_data.duplicated().value_counts()
# Out:
# False    185687
# dtype: int64

# %% [markdown]
# #### Get rid of invalid dates in order date column

# %%
#find text in order date 
temp_df=all_data[all_data['Order Date'].str[0:2]=='Or']
temp_df.head()
# Out:
#      Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 517  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#      Purchase Address
# 517  Purchase Address

# %%
# create a dataframe without or in order date
all_data=all_data[all_data['Order Date'].str[0:2]!='Or']
all_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1        176559  Bose SoundSport Headphones                1      99.99
# 2        176560                Google Phone                1        600
# 3        176560            Wired Headphones                1      11.99
# 4        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186300   259353      AAA Batteries (4-pack)                3       2.99
# 186301   259354                      iPhone                1        700
# 186302   259355                      iPhone                1        700
# 186303   259356      34in Ultrawide Monitor                1     379.99
# 186304   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %% [markdown]
# ###### Check column Type

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185686 entries, 0 to 186304
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185686 non-null  object
#  1   Product           185686 non-null  object
#  2   Quantity Ordered  185686 non-null  object
#  3   Price Each        185686 non-null  object
#  4   Order Date        185686 non-null  object
#  5   Purchase Address  185686 non-null  object
# dtypes: object(6)
# memory usage: 9.9+ MB

# %% [markdown]
# - Price Each & Quantity Ordered Pandas read them as object instead of numbers
# - We need to convert them to the corrrect data type

# %% [markdown]
# ###### Convert columns to correct data type

# %%
#make int
all_data['Quantity Ordered'] = pd.to_numeric(all_data['Quantity Ordered'])

# make float 
all_data['Price Each'] = pd.to_numeric(all_data['Price Each'])

# %%
all_data.dtypes
# Out:
# Order ID             object
# Product              object
# Quantity Ordered      int64
# Price Each          float64
# Order Date           object
# Purchase Address     object
# dtype: object

# %% [markdown]
# ## Feature Engineering
#
# The process of using domain knowledge to extract features from raw data.

# %%
# Create a new column called month.
# First change the Order Date columns from object type to Datetime
all_data['Order Date'] = pd.to_datetime(all_data['Order Date'])

# %%
all_data['month'] = all_data['Order Date'].dt.month
# We can also use the two methods below to do the same.

# %%
# all_data['Order Date'] = all_data['Order Date'].astype('datetime64[ns]')
# all_data['month'] = all_data['Order Date'].dt.month

# %%
## extract the first 2 digits in order date 
#all_data['Month'] = all_data['Order Date'].str[0:2]
## convert to Integer 
#all_data['Month'] = all_data['Month'].astype('int64')
 
#all_data.head()

# %%
all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 1        176559  Bose SoundSport Headphones                 1       99.99
# 2        176560                Google Phone                 1      600.00
# 3        176560            Wired Headphones                 1       11.99
# 4        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186300   259353      AAA Batteries (4-pack)                 3        2.99
# 186301   259354                      iPhone                 1      700.00
# 186302   259355                      iPhone                 1      700.00
# 186303   259356      34in Ultrawide Monitor                 1      379.99
# 186304   259357        USB-C Charging Cable                 1       11.95
#
#                 Order Date                         Purchase Address  month
# ...

# %% [markdown]
# ### Add sales column
# - Multiply the quantity ordered by the price.

# %%
all_data['Sales'] = all_data['Quantity Ordered'] * all_data['Price Each']

# %%
all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 1        176559  Bose SoundSport Headphones                 1       99.99
# 2        176560                Google Phone                 1      600.00
# 3        176560            Wired Headphones                 1       11.99
# 4        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186300   259353      AAA Batteries (4-pack)                 3        2.99
# 186301   259354                      iPhone                 1      700.00
# 186302   259355                      iPhone                 1      700.00
# 186303   259356      34in Ultrawide Monitor                 1      379.99
# 186304   259357        USB-C Charging Cable                 1       11.95
#
#                 Order Date                         Purchase Address  month  \
# ...

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ###### 1) What was the best month for sales? How much was earned that month?

# %%
#TOTAL SALES
all_data['Sales'].sum()
# Out:
# 34465537.94

# %%
monthly_sales = all_data.groupby('month').sum()
monthly_sales
# Out:
#        Quantity Ordered    Price Each         Sales
# month
# 1                 10893  1.810925e+06  1.821413e+06
# 2                 13431  2.186940e+06  2.200078e+06
# 3                 16979  2.789085e+06  2.804973e+06
# 4                 20536  3.366219e+06  3.389218e+06
# 5                 18653  3.133135e+06  3.150616e+06
# 6                 15234  2.560504e+06  2.576280e+06
# 7                 16054  2.631225e+06  2.646461e+06
# 8                 13429  2.226964e+06  2.241083e+06
# 9                 13091  2.081898e+06  2.094466e+06
# 10                22669  3.713609e+06  3.734778e+06
# 11                19769  3.178873e+06  3.197875e+06
# 12                28074  4.583268e+06  4.608296e+06

# %%
import matplotlib.pyplot as plt
months =range(1,13)
plt.bar(months,monthly_sales['Sales']/1000000)
plt.xticks(months)
plt.ylabel('sales in usd (millions) ')
plt.xlabel('Month number ')
plt.show()

# %% [markdown]
# ### 2) What city sold the most product?
# ###### Add city column

# %%
all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 1        176559  Bose SoundSport Headphones                 1       99.99
# 2        176560                Google Phone                 1      600.00
# 3        176560            Wired Headphones                 1       11.99
# 4        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186300   259353      AAA Batteries (4-pack)                 3        2.99
# 186301   259354                      iPhone                 1      700.00
# 186302   259355                      iPhone                 1      700.00
# 186303   259356      34in Ultrawide Monitor                 1      379.99
# 186304   259357        USB-C Charging Cable                 1       11.95
#
#                 Order Date                         Purchase Address  month  \
# ...

# %%
def get_city(address):
    return address.split(",")[1].strip(" ")

def get_state(address):
    return address.split(",")[2].split(" ")[1]
all_data['City'] = all_data['Purchase Address'].apply(lambda x : f'{get_city(x)}, {get_state(x)}')
all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 1        176559  Bose SoundSport Headphones                 1       99.99
# 2        176560                Google Phone                 1      600.00
# 3        176560            Wired Headphones                 1       11.99
# 4        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186300   259353      AAA Batteries (4-pack)                 3        2.99
# 186301   259354                      iPhone                 1      700.00
# 186302   259355                      iPhone                 1      700.00
# 186303   259356      34in Ultrawide Monitor                 1      379.99
# 186304   259357        USB-C Charging Cable                 1       11.95
#
#                 Order Date                         Purchase Address  month  \
# ...

# %% [markdown]
# #### What city sold the most product?

# %%
sales_by_city = all_data.groupby(['City']).sum().sort_values(by='Sales', ascending=False).reset_index(level=0)

# %%
sales_by_city
# Out:
#                 City  Quantity Ordered    Price Each   month         Sales
# 0  San Francisco, CA             50169  8.204001e+06  314949  8.254744e+06
# 1    Los Angeles, CA             33247  5.417172e+06  208020  5.448304e+06
# 2  New York City, NY             27903  4.632921e+06  175557  4.661867e+06
# 3         Boston, MA             22494  3.634398e+06  140898  3.658628e+06
# 4        Atlanta, GA             16584  2.778609e+06  104649  2.794199e+06
# 5         Dallas, TX             16707  2.750026e+06  104447  2.765374e+06
# 6        Seattle, WA             16534  2.730587e+06  104817  2.745046e+06
# 7       Portland, OR             11291  1.859836e+06   70517  1.870011e+06
# 8         Austin, TX             11137  1.808340e+06   69720  1.818044e+06
# 9       Portland, ME              2746  4.467524e+05   17119  4.493214e+05

# %%
plt.bar(sales_by_city['City'], sales_by_city['Sales'])
plt.ylabel('Sales in USD ($)')
plt.xlabel('City')
plt.xticks(sales_by_city['City'].values, rotation='vertical', size=8)
plt.show()

# %% [markdown]
# #### 3) What time should we display advertisements to maximize the likelihood of customer’s buying product?

# %%
# Add hour column  
all_data['Hour'] = all_data['Order Date'].dt.hour
# Add minute column
all_data['Minute'] = all_data['Order Date'].dt.minute

# %%
sales_per_hr = all_data.groupby('Hour')['Order ID'].count().reset_index(level=0, name='Orders')
sales_per_hr
# Out:
#     Hour  Orders
# 0      0    3902
# 1      1    2347
# 2      2    1242
# 3      3     830
# 4      4     852
# 5      5    1320
# 6      6    2481
# 7      7    4002
# 8      8    6252
# 9      9    8740
# 10    10   10929
# 11    11   12392
# 12    12   12573
# 13    13   12115
# 14    14   10965
# 15    15   10159
# 16    16   10359
# 17    17   10884
# 18    18   12263
# 19    19   12886
# 20    20   12218
# 21    21   10905
# 22    22    8808
# 23    23    6262

# %%
plt.plot(sales_per_hr['Hour'], sales_per_hr['Orders'])
plt.xticks(sales_per_hr['Hour'])
plt.grid()
plt.show()

# %% [markdown]
# #### 4) What products are most often sold together?

# %% [markdown]
# ###### Group product with the same order id
#
# - Groupby the 'Order ID' and 'Product' columns, then call transform which will return data aligned to the original df
# - Apply a lambda where we join the text entries:

# %%
df = all_data
df['Grouped'] = all_data.groupby('Order ID')['Product'].transform(lambda x:','.join(x))
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 1 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 2 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 4 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#               City  Hour  Minute                        Grouped
# ...

# %% [markdown]
# #### Drop Duplicates

# %%
df = df[['Order ID','Grouped']].drop_duplicates()
df.head()
# Out:
#   Order ID                        Grouped
# 0   176558           USB-C Charging Cable
# 1   176559     Bose SoundSport Headphones
# 2   176560  Google Phone,Wired Headphones
# 4   176561               Wired Headphones
# 5   176562           USB-C Charging Cable

# %% [markdown]
# ##### Count pairs that arise from combinations in your product lists.¶

# %%
from itertools import combinations
from collections import Counter

count =Counter()

for row in df['Grouped']:
    row_list =row.split(',')
    count.update(Counter(combinations(row_list, 2)))
    
count.most_common(10)
# Out:
# [(('iPhone', 'Lightning Charging Cable'), 1002),
#  (('Google Phone', 'USB-C Charging Cable'), 985),
#  (('iPhone', 'Wired Headphones'), 447),
#  (('Google Phone', 'Wired Headphones'), 413),
#  (('Vareebadd Phone', 'USB-C Charging Cable'), 361),
#  (('iPhone', 'Apple Airpods Headphones'), 360),
#  (('Google Phone', 'Bose SoundSport Headphones'), 220),
#  (('USB-C Charging Cable', 'Wired Headphones'), 159),
#  (('Vareebadd Phone', 'Wired Headphones'), 143),
#  (('Lightning Charging Cable', 'Wired Headphones'), 92)]

# %% [markdown]
# #### 5) What product sold the most? Why do you think it sold the most?

# %%
sales_per_product = all_data.groupby('Product').sum()['Quantity Ordered'].reset_index(level=0, name='Quantity')
sales_per_product
# Out:
#                        Product  Quantity
# 0                 20in Monitor      4126
# 1       27in 4K Gaming Monitor      6239
# 2             27in FHD Monitor      7541
# 3       34in Ultrawide Monitor      6192
# 4        AA Batteries (4-pack)     27615
# 5       AAA Batteries (4-pack)     30986
# 6     Apple Airpods Headphones     15637
# 7   Bose SoundSport Headphones     13430
# 8                Flatscreen TV      4813
# 9                 Google Phone      5529
# 10                    LG Dryer       646
# 11          LG Washing Machine       666
# 12    Lightning Charging Cable     23169
# 13          Macbook Pro Laptop      4725
# 14             ThinkPad Laptop      4128
# 15        USB-C Charging Cable     23931
# 16             Vareebadd Phone      2068
# 17            Wired Headphones     20524
# 18                      iPhone      6847

# %%
plt.bar(sales_per_product['Product'], sales_per_product['Quantity'])
plt.xticks(sales_per_product['Product'].values, rotation='vertical', size=8)
plt.show()

# %%
prices = all_data.groupby('Product').mean()['Price Each'].reset_index(level=0, name='Price')

# %%
prices
# Out:
#                        Product    Price
# 0                 20in Monitor   109.99
# 1       27in 4K Gaming Monitor   389.99
# 2             27in FHD Monitor   149.99
# 3       34in Ultrawide Monitor   379.99
# 4        AA Batteries (4-pack)     3.84
# 5       AAA Batteries (4-pack)     2.99
# 6     Apple Airpods Headphones   150.00
# 7   Bose SoundSport Headphones    99.99
# 8                Flatscreen TV   300.00
# 9                 Google Phone   600.00
# 10                    LG Dryer   600.00
# 11          LG Washing Machine   600.00
# 12    Lightning Charging Cable    14.95
# 13          Macbook Pro Laptop  1700.00
# 14             ThinkPad Laptop   999.99
# 15        USB-C Charging Cable    11.95
# 16             Vareebadd Phone   400.00
# 17            Wired Headphones    11.99
# 18                      iPhone   700.00

# %%
fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax2.plot(prices['Product'], prices['Price'], color='red')
ax1.bar(sales_per_product['Product'], sales_per_product['Quantity'])

ax1.set_xlabel('Product Name')
ax1.set_ylabel('Quantity Ordered', color='g')
ax2.set_ylabel('Price ($)', color='b')
ax1.set_xticklabels(prices['Product'].values, rotation='vertical', size=8)
fig.show()
# Out:
# <ipython-input-319-a3835dbd8322>:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(prices['Product'].values, rotation='vertical', size=8)
# <ipython-input-319-a3835dbd8322>:11: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# Low price items fetch more sales quantity
