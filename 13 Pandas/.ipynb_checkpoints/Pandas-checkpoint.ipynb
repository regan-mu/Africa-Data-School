# %% [markdown]
# # PANDAS
#
# - Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation library for python.
# - Pandas is one of the most downloaded python libraries and it has great performance because is is built on top on Numpy.
# - It enables us to read and work with different types of data sources e.g CSV files, Databases, HTML, JSON, Excel Sheets.
# ###### Pandas is suited for different kinds of data.<br>
# - Tabular data with heterogeneously-typed columns, as in an SQL table or Excel spreadsheet
# - Ordered and unordered (not necessarily fixed-frequency) time series data.
# - Arbitrary matrix data with row and column labels.
# - Any other form of observational / statistical data sets.

# %% [markdown]
# ### Installing pandas with PIP
# pip install pandas

# %%
# # Alternatively, if you're viewing this article in a Jupyter notebook you can run this cell to install pandas
# !pip install pandas

# %% [markdown]
# ### Installing pandas with conda
# conda install pandas

# %%
# To load the pandas package and start working with it, import the package. 
# we usually import it with a shorter name pd.
import pandas as pd

#check  the version of pandas 
print(pd.__version__)
# Out:
# 1.2.4

# %% [markdown]
# ###### Pandas Data Structures.
# - There are two core objects in pandas: the <b>DataFrame</b> and the <b>Series.</b>
# - A <b>Dataframe</b> is two dimensional data structure that is aligned in tabular format i.e in row and columns.
# - A <b>Series</b>, by contrast, is a sequence of data values. If a DataFrame is a table, then a Series is a list.
# - Each column in a Dataframe is a <b>Series</b>.
# - Pandas also has a 3-dimensional data structure known as a <b>Panel</b>

# %% [markdown]
# ##### Dataframe
# ![dataframe](img/pandas_data_structure.png)
# ##### Panel
# ![dataframe](img/panel.jpg)

# %% [markdown]
# ### Creating a Dataframe
# - To create a pandas dataframe we can pass a dictionary to pandas's **DataFrame()**  class.
# - Each dictionary key is the column name and values is the list of entries in each column.
# - The list of entries in each column must be the same.

# %%
athletes = {"Name": ["Stephen Curry", "Te'a Cooper", "Lebron James", "Serena Williams", "Simone Biles", 
                     "Giannis Antetokoumpo", "Naomi Osaka", 'Chris Paul'], 
            "Age": [33, 24, 36, 39, 24, 26, 23, 36], 
            "Gender": ["male", "female", "male", "female", "female", "male", "female", "male"]}

# pass student dictionary to the pandas DataFrame method:
df_athletes = pd.DataFrame(athletes)
df_athletes
# Out:
#                    Name  Age  Gender
# 0         Stephen Curry   33    male
# 1           Te'a Cooper   24  female
# 2          Lebron James   36    male
# 3       Serena Williams   39  female
# 4          Simone Biles   24  female
# 5  Giannis Antetokoumpo   26    male
# 6           Naomi Osaka   23  female
# 7            Chris Paul   36    male

# %%
# Create an empty Dataframe
df_0 = pd.DataFrame()
df_0
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#View the first 2 rows.
df_athletes.head()
# If the number of rows is not specified, the head method return the first 5 rows by default
# Out:
#               Name  Age  Gender
# 0    Stephen Curry   33    male
# 1      Te'a Cooper   24  female
# 2     Lebron James   36    male
# 3  Serena Williams   39  female
# 4     Simone Biles   24  female

# %%
#View the last 2 rows.
# If the number of rows is not specified, the head method return the last 5 rows by default
df_athletes.tail()
# Out:
#                    Name  Age  Gender
# 3       Serena Williams   39  female
# 4          Simone Biles   24  female
# 5  Giannis Antetokoumpo   26    male
# 6           Naomi Osaka   23  female
# 7            Chris Paul   36    male

# %% [markdown]
# # Reading and writing tabular data?

# %% [markdown]
# Pandas supports the integration with many file formats or data sources out of the box (csv, excel, sql, json, parquet, html,…). Importing data from each of these data sources is provided by function with the prefix read_*. Similarly, the to_* methods are used to store data.

# %% [markdown]
# ![title](img/panda_data.png)

# %% [markdown]
# ## Read CSV

# %%
df = pd.read_csv('data/Telco_Churn.csv')
# If we have a large dataset, by default pandas will display only the first 5 and the last 5 rows.
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# ## Read HTML

# %%
htdata = pd.read_html('https://en.wikipedia.org/wiki/Counties_of_Kenya')[2]
htdata.head()
htdata.to_csv("Kenya_Counties.csv")

# %%
htdata['Pop Growth'] = htdata['Population(2019 Census)'] - htdata['Population(2009 Census)']
htdata.head()
# Out:
#    Code            County FormerProvince  Area(km2)  Population(2009 Census)  \
# 0   1.0  Mombasa (County)          Coast      212.5                   939370
# 1   2.0             Kwale          Coast     8270.3                   649931
# 2   3.0            Kilifi          Coast    12245.9                  1109735
# 3   4.0        Tana River          Coast    35375.8                   240075
# 4   5.0              Lamu          Coast     6497.7                   191539
#
#    Population(2019 Census)         Capital  Pop Growth
# 0                  1208333  Mombasa (City)      268963
# 1                   866820           Kwale      216889
# 2                  1453787          Kilifi      344052
# 3                   315943            Hola       75868
# 4                   143920            Lamu      -47619

# %%
htdata['% Pop Growth'] = htdata['Pop Growth'] / htdata['Population(2009 Census)']
htdata.head()
# Out:
#    Code            County FormerProvince  Area(km2)  Population(2009 Census)  \
# 0   1.0  Mombasa (County)          Coast      212.5                   939370
# 1   2.0             Kwale          Coast     8270.3                   649931
# 2   3.0            Kilifi          Coast    12245.9                  1109735
# 3   4.0        Tana River          Coast    35375.8                   240075
# 4   5.0              Lamu          Coast     6497.7                   191539
#
#    Population(2019 Census)         Capital  Pop Growth  % Pop Growth
# 0                  1208333  Mombasa (City)      268963      0.286323
# 1                   866820           Kwale      216889      0.333711
# 2                  1453787          Kilifi      344052      0.310031
# 3                   315943            Hola       75868      0.316018
# 4                   143920            Lamu      -47619     -0.248613

# %% [markdown]
# ## Read EXCEL

# %%
#The equivalent read function to_excel() will reload the data to a DataFrame:
telcom_excel= pd.read_excel('data/telcom.xlsx', sheet_name=1)
telcom_excel.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# ## Read JSON

# %%
df = pd.read_json('data/testapi.json')
df.head()
# JSON -> JavaScript Object Notation.
# Its a light weight format for storing and exchanging data.
# Out:
#                        Name  Marks     Sex
# 0   Braund, Mr. Owen Harris     22    male
# 1  Allen, Mr. William Henry     35    male
# 2  Bonnell, Miss. Elizabeth     58  female

# %% [markdown]
# ## Read data from SQL
#
# If you’re working with data from a MySQL database you need to first establish a connection using an appropriate Python library, then pass a query to pandas.
#
# First, we need PyMySQL installed, so run this command in your terminal:
#
#     pip install PyMySQL
#
# <b>PyMySQL</b> is a MySQL database connector for python.
# - You can also use an **Object Relational Mapper (ORM)** eg sqlalchemy to connect to the db

# %%
# Or run this cell if you're in a notebook:
! pip install PyMySQL

# %%
import pymysql
conn = pymysql.connect (
    host='127.0.0.1',
    port=int(3306),
    user="root",
    passwd='@Qwerty254',
    db="jumiaa_store")

# %%
df = pd.read_sql_query("SELECT * FROM customers",conn)
df
# Out:
#    customer_id first_name  last_name  birth_date         phone    address  \
# 0            1        Joe     Mutale  1986-03-28  781-932-9754    0 Saace
# 1            2       Fred  Vilakati   1986-04-13  804-427-9456       Coml
# 2            3      Brian     Muyuda  1985-02-07  719-724-7869   Junction
# 3            4       John    Muchiri  1974-04-14  407-231-8017    Terrace
# 4            5    Clemmie      Banda  1973-11-07          None    5 Spohn
# 5            6       Elka   Nyambura  1991-09-04  312-480-8498    14Drive
# 6            7      Ilene      Otile  1964-08-30  615-641-4759   Crossing
# 7            8      Chirs      Brown  1993-07-17  941-527-3977     Center
# 8            9     Mutula    Kilonzo  1992-05-23  559-181-3744      Trail
# 9           10      Uhuru     Corupt  1969-10-13  404-246-3370     Avenue
#
#       city state  points
# 0  Nairobi    MA    2273
# 1     Cape    VA     947
# 2   Dodoma    CO    2967
# 3  Mombasa    FL     457
# ...

# %% [markdown]
# ## Converting back to a CSV, JSON

# %%
# to csv
df_athletes.to_csv('athletes.csv')
# to Json
df_athletes.to_json('athletes.json')

# %% [markdown]
# # Selecting a subset of a table.
# - Selecting or filtering specific rows and/or columns.
# - Filtering the data on a condition.
# - Methods for slicing, selecting, and extracting the data you need are available in Pandas.

# %% [markdown]
# ![title](img/subset.png)

# %% [markdown]
# ### Accessing Individual columns.

# %% [markdown]
# ###### using the dot notations
# - dataframe.column_name

# %%
df_athletes
# Out:
#                    Name  Age  Gender
# 0         Stephen Curry   33    male
# 1           Te'a Cooper   24  female
# 2          Lebron James   36    male
# 3       Serena Williams   39  female
# 4          Simone Biles   24  female
# 5  Giannis Antetokoumpo   26    male
# 6           Naomi Osaka   23  female
# 7            Chris Paul   36    male

# %%
df_athletes.Name
# Out:
# 0           Stephen Curry
# 1             Te'a Cooper
# 2            Lebron James
# 3         Serena Williams
# 4            Simone Biles
# 5    Giannis Antetokoumpo
# 6             Naomi Osaka
# 7              Chris Paul
# Name: Name, dtype: object

# %% [markdown]
# ###### Using the Bracket Notation.

# %%
df_athletes['Name']
# Out:
# 0           Stephen Curry
# 1             Te'a Cooper
# 2            Lebron James
# 3         Serena Williams
# 4            Simone Biles
# 5    Giannis Antetokoumpo
# 6             Naomi Osaka
# 7              Chris Paul
# Name: Name, dtype: object

# %%
type(df_athletes.Age)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ###### Selecting Multiple columns
# - We cannot use dot notation to select multiple columns.

# %%
df_athletes[['Gender', 'Age']]
# Out:
#    Gender  Age
# 0    male   33
# 1  female   24
# 2    male   36
# 3  female   39
# 4  female   24
# 5    male   26
# 6  female   23
# 7    male   36

# %%
type(df_athletes[['Name', 'Age']])
# Out:
# pandas.core.frame.DataFrame

# %%
df_athletes.shape
# Out:
# (8, 3)

# %% [markdown]
# ### Accessing individual ROWS.
# - Dataframes are indexed from zero.
# - We use the index to select individual rows or even multiple row.

# %%
df_athletes
# Out:
#                    Name  Age  Gender
# 0         Stephen Curry   33    male
# 1           Te'a Cooper   24  female
# 2          Lebron James   36    male
# 3       Serena Williams   39  female
# 4          Simone Biles   24  female
# 5  Giannis Antetokoumpo   26    male
# 6           Naomi Osaka   23  female
# 7            Chris Paul   36    male

# %%
# Returns a dataframe structure.
df_athletes.iloc[2]
# Out:
# Name      Lebron James
# Age                 36
# Gender            male
# Name: 2, dtype: object

# %% [markdown]
# #### Select Multiple Rows

# %%
df_athletes.iloc[1:4]
# Will select the the 1st but not including the 4th index.
# Returns a dataframe structure.
# Out:
#               Name  Age  Gender
# 1      Te'a Cooper   24  female
# 2     Lebron James   36    male
# 3  Serena Williams   39  female

# %% [markdown]
# #### Select a specific cell.

# %%
df_athletes.iloc[5,0]
# Out:
# 'Giannis Antetokoumpo'

# %% [markdown]
# #### Select rows with Logic
# - We can select a subset of a a dataframe using logical expressions.<br><b>(>=, >, <=, <, ==, !=)</b>
# - General syntax => <b>dataframe[dataframe.column_name == desired_value]</b> or <b>dataframe[dataframe['column_name'] == desired_value]</b>

# %%
df_athletes[df_athletes.Gender == 'female']
# Out:
#               Name  Age  Gender
# 1      Te'a Cooper   24  female
# 3  Serena Williams   39  female
# 4     Simone Biles   24  female
# 6      Naomi Osaka   23  female

# %%
df_athletes[df_athletes['Age'] > 30]
# Out:
#               Name  Age  Gender
# 0    Stephen Curry   33    male
# 2     Lebron James   36    male
# 3  Serena Williams   39  female
# 7       Chris Paul   36    male

# %% [markdown]
# #### Select with Multiple Conditions
# - Suppose we wanted rows where there are two conditions to be met.
# - eg if age > 30 and gender = male.

# %%
df_athletes[(df_athletes.Age < 30) | (df_athletes.Gender == 'female')]
# Out:
#                    Name  Age  Gender
# 1           Te'a Cooper   24  female
# 3       Serena Williams   39  female
# 4          Simone Biles   24  female
# 5  Giannis Antetokoumpo   26    male
# 6           Naomi Osaka   23  female

# %% [markdown]
# #### Using the Pandas query() function

# %%
df_athletes.query('Age < 30 & Gender == "female"')
# Out:
#            Name  Age  Gender
# 1   Te'a Cooper   24  female
# 4  Simone Biles   24  female
# 6   Naomi Osaka   23  female

# %% [markdown]
# ### Data Summary.
# - Sometimes we want to get a summary of statistics for columns with numerical data.
# - <b>describe</b> method gives us a nice overview of the main aggregated values over each numeric column.

# %%
df_athletes.describe()
# Out:
#             Age
# count   8.00000
# mean   30.12500
# std     6.53425
# min    23.00000
# 25%    24.00000
# 50%    29.50000
# 75%    36.00000
# max    39.00000

# %% [markdown]
# - Other times we want to get the technical summary of the entire dataset.
# - i.e column names, missing values, column datatype etc.
# - In this case we use <b>info</b> method.

# %%
df_athletes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    8 non-null      object
#  1   Age     8 non-null      int64
#  2   Gender  8 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 320.0+ bytes

# %% [markdown]
# ###### Get the names of the columns in the dataframe.

# %%
df_athletes.columns
# Return a list of all columns in the dataframe.
# Out:
# Index(['Name', 'Age', 'Gender'], dtype='object')

# %% [markdown]
# #### Now let work with a real world dataset.

# %%
df = pd.read_csv('data/Telco_churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# ### Get the monthlycharges column

# %%
monthly_charges = df['MonthlyCharges']
monthly_charges.head()
# Out:
# 0    29.85
# 1    56.95
# 2    53.85
# 3    42.30
# 4    70.70
# Name: MonthlyCharges, dtype: float64

# %%
#To select multiple columns, use a list of column names within the selection brackets [].
revenue = df[["MonthlyCharges", "TotalCharges","Churn"]]
revenue.head()
# Out:
#    MonthlyCharges TotalCharges Churn
# 0           29.85        29.85    No
# 1           56.95       1889.5    No
# 2           53.85       108.15   Yes
# 3           42.30      1840.75    No
# 4           70.70       151.65   Yes

# %% [markdown]
# ### I’m interested in the customers who paid more than 100 in MonthlyCharges

# %%
paid_above_100 = df[df["MonthlyCharges"] > 100]
paid_above_100.head()
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 12  8091-TTVAX    Male              0     Yes         No      58          Yes
# 13  0280-XJGEX    Male              0      No         No      49          Yes
# 14  5129-JLPIS    Male              0      No         No      25          Yes
# 15  3655-SNQYZ  Female              0     Yes        Yes      69          Yes
#
#    MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 8            Yes     Fiber optic             No  ...              Yes
# 12           Yes     Fiber optic             No  ...              Yes
# 13           Yes     Fiber optic             No  ...              Yes
# 14            No     Fiber optic            Yes  ...              Yes
# 15           Yes     Fiber optic            Yes  ...              Yes
#
# ...

# %% [markdown]
# ### Count the number of customers paid above 100.

# %%
paid_above_100.count()
# Out:
# customerID          902
# gender              902
# SeniorCitizen       902
# Partner             902
# Dependents          902
# tenure              902
# PhoneService        902
# MultipleLines       902
# InternetService     902
# OnlineSecurity      902
# OnlineBackup        902
# DeviceProtection    902
# TechSupport         902
# StreamingTV         902
# StreamingMovies     902
# Contract            902
# PaperlessBilling    902
# PaymentMethod       902
# MonthlyCharges      902
# TotalCharges        902
# Churn               902
# dtype: int64

# %% [markdown]
# ### Select customers who are paying for monthly and one year contract
# In this case we can use:
# - isin() method

# %%
df.head(2)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
#
#       PaymentMethod MonthlyCharges  TotalCharges Churn
# 0  Electronic check          29.85         29.85    No
# 1      Mailed check          56.95        1889.5    No
#
# [2 rows x 21 columns]

# %%
Contract_month_and_1year= df[df["Contract"].isin(['Month-to-month','One year'])  ]
Contract_month_and_1year.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# ### We want to work with customer data for which the Partner status is known.
# Using:
# - notna() method
# - notnull() method.

# %%
df["Partner"].isnull().any()
# Out:
# False

# %%
status_no_na = df[df["Partner"].notnull()]
status_no_na.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# ### Selecting rows and columns
#
# We have two options:
#
# - .loc - locates by row and column label.
# - .iloc- locates by row and column index.
#
# #### The main distinction between loc and iloc is:
# - loc is label-based, which means that you have to specify rows and columns based on their row and column labels.
# - iloc is integer position-based, so you have to specify rows and columns by their integer position values (index position).
# - Read more: https://towardsdatascience.com/how-to-use-loc-and-iloc-for-selecting-data-in-pandas-bd09cb4c3d79

# %% [markdown]
# ## Using iloc

# %% [markdown]
# ###### I’m interested in rows 10 till 25 and columns 3 to 5.

# %%
df.iloc[10:26, 2:5]
# Out:
#     SeniorCitizen Partner Dependents
# 10              0     Yes        Yes
# 11              0      No         No
# 12              0     Yes         No
# 13              0      No         No
# 14              0      No         No
# 15              0     Yes        Yes
# 16              0      No         No
# 17              0      No        Yes
# 18              0     Yes        Yes
# 19              0      No         No
# 20              1      No         No
# 21              0     Yes         No
# 22              0      No         No
# 23              0     Yes         No
# 24              0     Yes        Yes
# 25              0      No         No

# %% [markdown]
# #### Row 0 till 3 and column 3 and change the cells to "anonymous"

# %%
df.iloc[0:3, 3] = "anonymous"
df.head(5)
# Out:
#    customerID  gender  SeniorCitizen    Partner Dependents  tenure  \
# 0  7590-VHVEG  Female              0  anonymous         No       1
# 1  5575-GNVDE    Male              0  anonymous         No      34
# 2  3668-QPYBK    Male              0  anonymous         No       2
# 3  7795-CFOCW    Male              0         No         No      45
# 4  9237-HQITU  Female              0         No         No       2
#
#   PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0           No  No phone service             DSL             No  ...
# 1          Yes                No             DSL            Yes  ...
# 2          Yes                No             DSL            Yes  ...
# 3           No  No phone service             DSL            Yes  ...
# 4          Yes                No     Fiber optic             No  ...
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %% [markdown]
# ### Select rows 10, 1, 5, 700, 60, 26 and columns 18, 19, 20

# %%
df.iloc[[10, 1, 5, 700, 60, 26], [18, 19, 20]]
# Out:
#      MonthlyCharges TotalCharges Churn
# 10            49.95       587.45    No
# 1             56.95       1889.5    No
# 5             99.65        820.5   Yes
# 700           63.30       4189.7    No
# 60           100.50       4707.1    No
# 26            99.35      4749.15   Yes

# %% [markdown]
# ### Dropping the indices.
# - When we select a subset of data, we end up with non consecutive indices.
# - This make it hard to use iloc on that subset.
# - We can reset the indices using the <b>reset_index()</b> method.
# - If we want to drop them altogether, we can pass the argument <b>drop=True</b> to the reset_index() method.

# %%
data = df.iloc[[10, 1, 5, 700, 60, 26], [18, 19, 20]]
data.reset_index(inplace=True, drop=True)
data
# Out:
#    MonthlyCharges TotalCharges Churn
# 0           49.95       587.45    No
# 1           56.95       1889.5    No
# 2           99.65        820.5   Yes
# 3           63.30       4189.7    No
# 4          100.50       4707.1    No
# 5           99.35      4749.15   Yes

# %%
data
# Out:
#    MonthlyCharges TotalCharges Churn
# 0           49.95       587.45    No
# 1           56.95       1889.5    No
# 2           99.65        820.5   Yes
# 3           63.30       4189.7    No
# 4          100.50       4707.1    No
# 5           99.35      4749.15   Yes

# %% [markdown]
# ## Using loc

# %%
df.head(15)
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female              0     Yes         No       1           No
# 1   5575-GNVDE    Male              0      No         No      34          Yes
# 2   3668-QPYBK    Male              0      No         No       2          Yes
# 3   7795-CFOCW    Male              0      No         No      45           No
# 4   9237-HQITU  Female              0      No         No       2          Yes
# 5   9305-CDSKC  Female              0      No         No       8          Yes
# 6   1452-KIOVK    Male              0      No        Yes      22          Yes
# 7   6713-OKOMC  Female              0      No         No      10           No
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 9   6388-TABGU    Male              0      No        Yes      62          Yes
# 10  9763-GRSKD    Male              0     Yes        Yes      13          Yes
# ...

# %%
df.loc[[10, 1, 5, 700, 60, 26], ["MonthlyCharges", "TotalCharges","Churn"]]
# Out:
#      MonthlyCharges TotalCharges Churn
# 10            49.95       587.45    No
# 1             56.95       1889.5    No
# 5             99.65        820.5   Yes
# 700           63.30       4189.7    No
# 60           100.50       4707.1    No
# 26            99.35      4749.15   Yes

# %%
df.loc[10:26, ["MonthlyCharges", "TotalCharges","Churn"]]
# Out:
#     MonthlyCharges TotalCharges Churn
# 10           49.95       587.45    No
# 11           18.95        326.8    No
# 12          100.35       5681.1    No
# 13          103.70       5036.3   Yes
# 14          105.50      2686.05    No
# 15          113.25      7895.15    No
# 16           20.65      1022.95    No
# 17          106.70      7382.25    No
# 18           55.20       528.35   Yes
# 19           90.05       1862.9    No
# 20           39.65        39.65   Yes
# 21           19.80       202.25    No
# 22           20.15        20.15   Yes
# 23           59.90       3505.1    No
# 24           59.60       2970.3    No
# 25           55.30       1530.6    No
# 26           99.35      4749.15   Yes

# %% [markdown]
# We can also reset the index.

# %% [markdown]
# ### Adding a column.

# %%
df_athletes
# Out:
#                    Name  Age  Gender
# 0         Stephen Curry   33    male
# 1           Te'a Cooper   24  female
# 2          Lebron James   36    male
# 3       Serena Williams   39  female
# 4          Simone Biles   24  female
# 5  Giannis Antetokoumpo   26    male
# 6           Naomi Osaka   23  female
# 7            Chris Paul   36    male

# %%
df_athletes['Sport'] = ['Basketball', 'Basketball', 'Basketball', 'Tennis', 'Gymnastics', 'Basketball', 
                        'Tennis', 'Basketball']

# %%
df_athletes
# Out:
#                    Name  Age  Gender       Sport
# 0         Stephen Curry   33    male  Basketball
# 1           Te'a Cooper   24  female  Basketball
# 2          Lebron James   36    male  Basketball
# 3       Serena Williams   39  female      Tennis
# 4          Simone Biles   24  female  Gymnastics
# 5  Giannis Antetokoumpo   26    male  Basketball
# 6           Naomi Osaka   23  female      Tennis
# 7            Chris Paul   36    male  Basketball

# %% [markdown]
# ### Performing Column Operations.
# - For instance we want to make all words in a column to uppercase.
# - We can use the <b>apply</b> function to every value in a particular column.
# ###### Using lambda function.
# - Lambda function is basically shorthand for writing python function.
# - Lambda function dont have a name or a return statement.
# - Does not take take any arguments.

# %%
df_athletes['first_name'] = df_athletes['Name'].apply(lambda x:x.split(' ')[0])
df_athletes
# Out:
#                    Name  Age  Gender       Sport first_name
# 0         Stephen Curry   33    male  Basketball    Stephen
# 1           Te'a Cooper   24  female  Basketball       Te'a
# 2          Lebron James   36    male  Basketball     Lebron
# 3       Serena Williams   39  female      Tennis     Serena
# 4          Simone Biles   24  female  Gymnastics     Simone
# 5  Giannis Antetokoumpo   26    male  Basketball    Giannis
# 6           Naomi Osaka   23  female      Tennis      Naomi
# 7            Chris Paul   36    male  Basketball      Chris

# %%
def last_name(name):
    l_name = name.split(' ')[-1]
    return l_name

df_athletes['last_name'] = df_athletes['Name'].apply(last_name)

    
df_athletes
# Out:
#                    Name  Age  Gender       Sport first_name     last_name
# 0         Stephen Curry   33    male  Basketball    Stephen         Curry
# 1           Te'a Cooper   24  female  Basketball       Te'a        Cooper
# 2          Lebron James   36    male  Basketball     Lebron         James
# 3       Serena Williams   39  female      Tennis     Serena      Williams
# 4          Simone Biles   24  female  Gymnastics     Simone         Biles
# 5  Giannis Antetokoumpo   26    male  Basketball    Giannis  Antetokoumpo
# 6           Naomi Osaka   23  female      Tennis      Naomi         Osaka
# 7            Chris Paul   36    male  Basketball      Chris          Paul

# %%
df_athletes['age-5'] = df_athletes['Age'].apply(lambda x: x - 5)

# %%
df_athletes
# Out:
#                    Name  Age  Gender       Sport first_name     last_name  \
# 0         Stephen Curry   33    male  Basketball    Stephen         Curry
# 1           Te'a Cooper   24  female  Basketball       Te'a        Cooper
# 2          Lebron James   36    male  Basketball     Lebron         James
# 3       Serena Williams   39  female      Tennis     Serena      Williams
# 4          Simone Biles   24  female  Gymnastics     Simone         Biles
# 5  Giannis Antetokoumpo   26    male  Basketball    Giannis  Antetokoumpo
# 6           Naomi Osaka   23  female      Tennis      Naomi         Osaka
# 7            Chris Paul   36    male  Basketball      Chris          Paul
#
#    age-5
# 0     28
# 1     19
# 2     31
# 3     34
# 4     19
# 5     21
# 6     18
# 7     31

# %% [markdown]
# ###### Renaming Columns

# %%
df_athletes.rename(columns = {
    'Sport': 'Game'}, inplace=True)

# %%
df_athletes
# Out:
#                    Name  Age  Gender        Game first_name     last_name
# 0         Stephen Curry   33    male  Basketball    Stephen         Curry
# 1           Te'a Cooper   24  female  Basketball       Te'a        Cooper
# 2          Lebron James   36    male  Basketball     Lebron         James
# 3       Serena Williams   39  female      Tennis     Serena      Williams
# 4          Simone Biles   24  female  Gymnastics     Simone         Biles
# 5  Giannis Antetokoumpo   26    male  Basketball    Giannis  Antetokoumpo
# 6           Naomi Osaka   23  female      Tennis      Naomi         Osaka
# 7            Chris Paul   36    male  Basketball      Chris          Paul

# %% [markdown]
# ### Calculating Column Statistics.
# These commands include:
# - mean()
# - std()
# - median()
# - count()
# - nunique()
# - unique()

# %%
df_athletes['Age'].mean()
# Out:
# 30.125

# %% [markdown]
# ### Create new columns derived from existing columns.

# %% [markdown]
# ![cols](img/colums.png)
#
# Create a new column by assigning the output to the DataFrame with a new column name in between the [].
#
# Operations are element-wise, no need to loop over rows.

# %% [markdown]
# ### We want forecast montly sales in the next 10 months

# %%
df["ForecastMonthly"] = df["MonthlyCharges"] * 10
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...         Yes
# 4                No     Fiber optic             No  ...          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %% [markdown]
# ##### Map method
# - Map values of Series according to input correspondence.

# %%
df['gender'] = df['gender'].map({'Female': 1, 'Male': 0})

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen    Partner Dependents  tenure  \
# 0  7590-VHVEG       1              0  anonymous         No       1
# 1  5575-GNVDE       0              0  anonymous         No      34
# 2  3668-QPYBK       0              0  anonymous         No       2
# 3  7795-CFOCW       0              0         No         No      45
# 4  9237-HQITU       1              0         No         No       2
#
#   PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0           No  No phone service             DSL             No  ...
# 1          Yes                No             DSL            Yes  ...
# 2          Yes                No             DSL            Yes  ...
# 3           No  No phone service             DSL            Yes  ...
# 4          Yes                No     Fiber optic             No  ...
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %% [markdown]
# ### Calculating Aggregate Functions.

# %% [markdown]
# ###### Groupby Method.

# %%
#We want to get the churn for each gender.
churn_data_gender = df.groupby(['gender']).Churn.value_counts().reset_index(name='Total')
churn_data_gender
# Out:
#    gender Churn  Total
# 0  Female    No   2549
# 1  Female   Yes    939
# 2    Male    No   2625
# 3    Male   Yes    930

# %% [markdown]
# ### Pivot tables.
# - We use Pivot Tables to for reorganizing a dataframe.
# - This process is called <b>Pivoting</b>
# - The new table is called a <b> Pivot Table</b>

# %%
#Pivot table showing the churn between male and females.
churn_data_gender_pivot=churn_data_gender.pivot(columns='Churn', index = 'gender', values= 'Total')
churn_data_gender_pivot
# Out:
# Churn     No  Yes
# gender
# Female  2549  939
# Male    2625  930

# %% [markdown]
# ### Concatenate Dataframes
# - Sometimes a dataset is broken to multiple tables eg Data cans be split into multiple CSV files so that each download is smaller.
# - We therefore need to reconstruct a single Dataframe from multiple smaller dataframes, we can use the method <b>pd.concat([df1, df2, ___ dfn]) </b>
# - This method only works if all the columns are same in all dataframes.

# %%
athlete2 = {"Name": ['Joel Embiid', 'Megan Rapinoe', 'Didier Drogba'], 
            "Age": [29, 36, 43], 
            "Gender": ["Male", "Female", "Male"],
            "Game": ["Basketball", "Football", "Football"],
            "first_name": ["Joel", "Megan", "Didier"]}
df_athletes2 = pd.DataFrame(data=athlete2)

# %%
df_athletes2
# Out:
#             Name  Age  Gender        Game first_name
# 0    Joel Embiid   29    Male  Basketball       Joel
# 1  Megan Rapinoe   36  Female    Football      Megan
# 2  Didier Drogba   43    Male    Football     Didier

# %%
athlete_combined = pd.concat([df_athletes, df_athletes2]).reset_index(drop=True)

# %%
athlete_combined
# Out:
#                     Name  Age  Gender        Game first_name     last_name
# 0          Stephen Curry   33    male  Basketball    Stephen         Curry
# 1            Te'a Cooper   24  female  Basketball       Te'a        Cooper
# 2           Lebron James   36    male  Basketball     Lebron         James
# 3        Serena Williams   39  female      Tennis     Serena      Williams
# 4           Simone Biles   24  female  Gymnastics     Simone         Biles
# 5   Giannis Antetokoumpo   26    male  Basketball    Giannis  Antetokoumpo
# 6            Naomi Osaka   23  female      Tennis      Naomi         Osaka
# 7             Chris Paul   36    male  Basketball      Chris          Paul
# 8            Joel Embiid   29    Male  Basketball       Joel           NaN
# 9          Megan Rapinoe   36  Female    Football      Megan           NaN
# 10         Didier Drogba   43    Male    Football     Didier           NaN

# %% [markdown]
# # How to create plots in pandas?

# %% [markdown]
# ![title](img/plot.png)

# %% [markdown]
# The .plot.* methods are applicable on both Series and DataFrames
#
# By default, each of the columns is plotted as a different element (line, boxplot,…)
#
# Any plot created by pandas is a Matplotlib object.

# %%
df['Contract'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df["MonthlyCharges"].plot()
# Out:
# <AxesSubplot:>

# %%
df.tenure.plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Sort table rows¶

# %%
#Sort our data with sort_values method.
# By default, the data is sorted in asecnding order.
# If you want to sort in descending order, you pass another argument (ascending=False) to the sort_values method.
df.sort_values(by="MonthlyCharges").head()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 3719  6823-SIDFQ    Male              0      No         No      28
# 1529  9764-REAFF  Female              0     Yes         No      59
# 6652  0827-ITJPH    Male              0      No         No      36
# 6906  9945-PSVIP  Female              0     Yes        Yes      25
# 1156  0621-CXBKL  Female              0      No         No      53
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 3719          Yes            No              No  No internet service  ...
# 1529          Yes            No              No  No internet service  ...
# 6652          Yes            No              No  No internet service  ...
# 6906          Yes            No              No  No internet service  ...
# 1156          Yes            No              No  No internet service  ...
#
#               TechSupport          StreamingTV      StreamingMovies  Contract  \
# ...

# %% [markdown]
# ###### Want to sort  in descending order

# %%
df.sort_values(by=['gender', 'MonthlyCharges'], ascending=False).head()
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 5127  8199-ZLLSA   Male              0      No         No      67
# 6118  9924-JPRMC   Male              0      No         No      72
# 4610  2889-FPWRM   Male              0     Yes         No      72
# 3299  4282-MSACW   Male              0      No         No      68
# 5347  9788-HNGUT   Male              0     Yes         No      72
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 5127          Yes           Yes     Fiber optic            Yes  ...
# 6118          Yes           Yes     Fiber optic            Yes  ...
# 4610          Yes           Yes     Fiber optic            Yes  ...
# 3299          Yes           Yes     Fiber optic            Yes  ...
# 5347          Yes           Yes     Fiber optic            Yes  ...
#
#      TechSupport StreamingTV StreamingMovies  Contract PaperlessBilling  \
# 5127         Yes         Yes             Yes  One year              Yes
# ...

# %% [markdown]
# ## Read More
#
# https://github.com/LearnDataSci/articles/blob/master/Python%20Pandas%20Tutorial%20A%20Complete%20Introduction%20for%20Beginners/notebook.ipynb
#
# ​
